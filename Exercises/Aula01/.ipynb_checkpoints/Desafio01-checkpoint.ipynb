# %% [markdown]
# Analisando os dados propriamente

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# |  **X**   |  **Y**   | **Cor**     |
# | -------- | -------- | ----------- |
# | 47       | 38       | red         |
# | 62       | 62       | blue        |
# | 65       | 53       | green       |
# | 70       | 67       | purple      |
# | 70       | 84       | orange      |
# | 78       | 79       | brown       |
# | 95       | 93       | pink        |
# | 100      | 106      | gray        |
# | 114      | 117      | olive       |
# | 118      | 116      | cyan        |
# | 124      | 127      | magenta     |
# | 127      | 114      | yellow      |
# | 140      | 134      | black       |
# | 140      | 139      | lime        |
# | 140      | 142      | navy        |
# | 150      | 170      | teal        |
# | 152      | 149      | maroon      |
# | 164      | 154      | gold        |
# | 198      | 200      | silver      |
# | 221      | 215      | coral       |

# %%
x = [47, 62, 65, 70, 70, 78, 95, 100, 114, 118, 124, 127, 140, 140, 140, 150, 152, 164, 198, 221]
y = [38, 62, 53, 67, 84, 79, 93, 106, 117, 116, 127, 114, 134, 139, 142, 170, 149, 154, 200, 215]


# Lista de cores
colors = ['red', 'blue', 'green', 'purple', 'orange', 'brown', 'pink', 'gray', 'olive', 'cyan', 'magenta', 'yellow', 'black', 'lime', 'navy', 'teal', 'maroon', 'gold', 'silver', 'coral']

plt.scatter(x, y, c=colors)
#plt.xlim(0,2)   #axis x método de cromatografia gasosa
#plt.ylim(0,5)   #axis y método novo

plt.title('Gráfico de dispersão')
plt.xlabel('método de cromatografia gasosa')
plt.ylabel('método novo')
# Out:
# Text(0, 0.5, 'método novo')
