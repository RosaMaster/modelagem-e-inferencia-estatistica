# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# |  ASO  | Largura da Pálpebra |
# | ----- | ------------------- |
# | 1.02  | 0.40                |
# | 1.21  | 0.42                |
# | 0.88  | 0.48                |
# | 0.98  | 0.51                |
# | 1.52  | 0.57                |
# | 1.83  | 0.60                |
# | 1.50  | 0.70                |
# | 1.80  | 0.75                |
# | 1.74  | 0.75                |
# | 1.63  | 0.78                |
# | 2.00  | 0.84                |
# | 2.80  | 0.95                |
# | 2.48  | 0.99                |
# | 2.47  | 1.03                |
# | 3.05  | 1.12                |
# | 3.18  | 1.15                |
# | 3.76  | 1.20                |
# | 3.68  | 1.25                |
# | 3.82  | 1.25                |
# | 3.21  | 1.28                |
# | 4.27  | 1.30                |
# | 3.12  | 1.34                |
# | 3.99  | 1.37                |
# | 3.75  | 1.40                |
# | 4.10  | 1.43                |
# | 4.18  | 1.46                |
# | 3.77  | 1.49                |
# | 4.34  | 1.55                |
# | 4.21  | 1.58                |
# | 4.92  | 1.60                |

# %%
aso = [1.02, 1.21, 0.88, 0.98, 1.52, 1.83, 1.50, 1.80, 1.74, 1.63, 2.00, 2.80, 2.48, 2.47, 3.05, 3.18, 3.76, 3.68, 3.82, 3.21, 4.27, 3.12, 3.99, 3.75, 4.10, 4.18, 3.77, 4.34, 4.21, 4.92]  

largura_da_palpebra = [0.40, 0.42, 0.48, 0.51, 0.57, 0.60, 0.70, 0.75, 0.75, 0.78, 0.84, 0.95, 0.99, 1.03, 1.12, 1.15, 1.20, 1.25, 1.25, 1.28, 1.30, 1.34, 1.37, 1.40, 1.43, 1.46, 1.49, 1.55, 1.58, 1.60] 

plt.scatter(aso, largura_da_palpebra)

plt.title('Gráfico de Dispersão')
plt.xlabel('dispersão de Área de Superfície Ocular (ASO)')
plt.ylabel('largura da pálpebra')
# Out:
# Text(0, 0.5, 'largura da pálpebra')
